# %%
"""
erratics-layers.ipynb

Demonstrates how to:
- Read a CSV of glacial erratics (lat/lon).
- Use ArcGIS Python API with an API key (anonymous-like user) to query real
   feature services for rivers and coastlines (in a bounding box).
- Perform local proximity analysis with Shapely (buffer/intersect in projected coordinates).
- Display results in an ArcGIS MapView with toggleable layers (no publishing),
   specifically:
      - All erratics
      - Close to rivers
      - Close to coast
Optimized spatial analysis to:
- Precompute projections for all geometries.
- Build spatial indexes using Rtree for proximity queries.
- Dramatically reduce computation time.
"""

import os
import csv

import pyproj
import shapely.ops
from shapely.geometry import Point

from arcgis.gis import GIS
from arcgis.features import FeatureLayer, Feature, FeatureSet
from arcgis.map.symbols import SimpleMarkerSymbolEsriSMS, SimpleLineSymbolEsriSLS, SimpleMarkerSymbolStyle
from arcgis.map.popups import PopupInfo
from arcgis.geometry import Geometry

from rtree import index

# %%
###############################################################################
# 2. READ CSV OF ERRATICS
###############################################################################

def read_erratics_csv(csv_path):
    """
    Reads a csv with these columns:
       row[1] = latitude,
       row[2] = longitude,
       row[6] = id,
       row[7] = name
    Returns a list of dicts: [{"id":"ERR001", "name":"...", "lat":47..., "lon":-122...}, ...]
    """
    data = []
    with open(csv_path, mode='r', encoding='utf-8-sig') as f:
        reader = csv.reader(f)
        header = next(reader)  # skip header
        for row in reader:
            lat = float(row[1])
            lon = float(row[2])
            eid = row[6]
            ename = row[7]
            data.append({
                "id": eid,
                "name": ename,
                "lat": lat,
                "lon": lon
            })
    return data

# %%
###############################################################################
# 3. ARCGIS FEATURE SERVICE URLS
###############################################################################

# Real data from ArcGIS Online
RIVERS_URL = "https://services1.arcgis.com/ZIL9uO234SBBPGL7/ArcGIS/rest/services/Rivers_World_Natural_Earth/FeatureServer/0"
COAST_URL =  "https://services7.arcgis.com/WSiUmUhlFx4CtMBB/ArcGIS/rest/services/GSHHS_GlobalCoastlines_HighResolution/FeatureServer/0"

# %%
###############################################################################
# 4. PROXIMITY UTILS
###############################################################################

def reproject_point(point_geometry, from_crs="EPSG:4326", to_crs="EPSG:3857"):
    """Reproject a Shapely Point using pyproj for distance-based calculations."""
    project_func = pyproj.Transformer.from_crs(
        from_crs, to_crs, always_xy=True
    ).transform
    return shapely.ops.transform(project_func, point_geometry)

def is_point_within_distance(point_lonlat, list_of_features, distance_meters):
    """
    Return True if 'point_lonlat' (Shapely, EPSG:4326) is within
    'distance_meters' of ANY geometry in 'list_of_features'.
    """
    point_3857 = reproject_point(point_lonlat, "EPSG:4326", "EPSG:3857")
    for feat_4326 in list_of_features:
        feat_3857 = reproject_point(feat_4326, "EPSG:4326", "EPSG:3857")
        if point_3857.distance(feat_3857) <= distance_meters:
            return True
    return False

# %%
###############################################################################
# 5. HELPER: CONVERT FeatureSet --> LIST OF SHAPELY GEOMETRIES
###############################################################################

def fs_to_shapely_list(fs):
    """
    Convert an ArcGIS FeatureSet to a list of Shapely geometries.
    Uses arcgis.geometry.Geometry(...) + .as_shapely for robust conversion.
    Skips null or empty geometry.
    """
    geoms = []
    null_count = 0
    fail_count = 0
    
    for f in fs.features:
        if f.geometry is None:
            null_count += 1
            continue
        
        try:
            arc_geom = Geometry(f.geometry)
            if arc_geom.is_empty:
                null_count += 1
                continue
            sgeom = arc_geom.as_shapely
            if sgeom and not sgeom.is_empty:
                geoms.append(sgeom)
            else:
                null_count += 1
        except Exception:
            fail_count += 1
    
    if null_count > 0:
        print(f"[WARN] Skipped {null_count} empty or null geoms.")
    if fail_count > 0:
        print(f"[WARN] Conversion failed for {fail_count} geoms.")
    return geoms

# %%
###############################################################################
# A) READ LOCAL CSV
###############################################################################

CSV_PATH = "erratics_gis.csv"

erratics = read_erratics_csv(CSV_PATH)
print(f"Loaded {len(erratics)} erratics from {CSV_PATH}.")
# Out:
# Loaded 213 erratics from erratics_gis.csv.

# %%
###############################################################################
# B) Connect to ArcGIS via API key
###############################################################################

API_KEY = "AAPTxy8BH1VEsoebNVZXo8HurNF06YWHEbns1XWgxHCpzlyDjxh3Rx8dbWwLv-YhpjbuKnTT5uOWTO7-WskSkafBC6jiu1QCJUkLpyb-6epQoRGSlLogeBqx_bwJSceJjPn7ooXJnbZwuuPl8jcPSv014Zrv8X5lK7aDfBFPPUlt8dfqMsy9ZZtrxkFKKrL9bRIhoJZTDuTzFRhIgV43IhOe3YtvXO7xAuynlg14irzQnV8.AT1_TRlM9H04"  # <-- replace with your real key
gis = GIS(api_key=API_KEY)
if gis.users.me is not None:
    print("[INFO] Named user or full developer account.")
else:
    print("[INFO] Using anonymous-like user with API key.")
# Out:
# [INFO] Using anonymous-like user with API key.

# %%
###############################################################################
# C) Bounding box for North America to limit queries
###############################################################################

# lat_min       lat_max     lon_min     lon_max
# ymin          ymax        xmin        xmax
# 19.2726009	19.5926009	-99.2933416	-98.9733416 <- Mexico
# 41.6765556	83.3362128	-141.00275	-52.3231981 <- Canada

NA_BBOX = {
    "xmin": -141,
    "ymin": 42,
    "xmax": -52,
    "ymax": 83,
    "spatialReference": {"wkid": 4326}
}

# %%
###############################################################################
# D) Query rivers and coast
###############################################################################

rivers_layer = FeatureLayer(RIVERS_URL, gis=gis)
coast_layer  = FeatureLayer(COAST_URL,  gis=gis)

print("[INFO] Querying rivers within bounding box...")
rivers_fs = rivers_layer.query(
    geometry=NA_BBOX,
    geometry_type="esriGeometryEnvelope",
    in_sr=4326,
    out_sr=4326,
    where="1=1",
    return_geometry=True
)
print(f" -> fetched {len(rivers_fs.features)} river features.")

print("[INFO] Querying coast within bounding box...")
coast_fs = coast_layer.query(
    geometry=NA_BBOX,
    geometry_type="esriGeometryEnvelope",
    in_sr=4326,
    out_sr=4326,
    where="1=1",
    return_geometry=True
)
print(f" -> fetched {len(coast_fs.features)} coast features.")

rivers_geomlist = fs_to_shapely_list(rivers_fs)
coast_geomlist  = fs_to_shapely_list(coast_fs)

print(f"[INFO] Rivers geometry count: {len(rivers_geomlist)}")
print(f"[INFO] Coast geometry count:  {len(coast_geomlist)}")
# Out:
# [INFO] Querying rivers within bounding box...
#  -> fetched 140 river features.
# [INFO] Querying coast within bounding box...
#  -> fetched 31629 coast features.
# [INFO] Rivers geometry count: 140
# [INFO] Coast geometry count:  31629

# %%
###############################################################################
# E) Proximity checks
###############################################################################

RIVER_DISTANCE = 1000.0  # 1 km
COAST_DISTANCE = 2000.0  # 2 km

results = []
for e in erratics:
    pt = Point(e["lon"], e["lat"])
    close_river = is_point_within_distance(pt, rivers_geomlist, RIVER_DISTANCE)
    close_coast = is_point_within_distance(pt, coast_geomlist,  COAST_DISTANCE)

    results.append({
        "id":   e["id"],
        "name": e["name"],
        "lon":  e["lon"],
        "lat":  e["lat"],
        "close_river":  close_river,
        "close_coast":  close_coast
    })

print(f"[INFO] Completed proximity analysis for {len(results)} erratics.")
# Out:
# [INFO] Completed proximity analysis for 213 erratics.

# %%
###############################################################################
# F) Create toggleable layers in the ArcGIS Map
###############################################################################

def make_featureset(records, layer_label):
    """
    Build a fully defined FeatureSet: 
        - geometry_type='esriGeometryPoint'
        - spatial_reference={"wkid":4326}
        - fields: an array describing each attribute
    """
    # 1) Build a list of arcgis.features.Feature
    feats = []
    for r in records:
        geom = {
            "x": r["lon"],
            "y": r["lat"],
            "spatialReference": {"wkid": 4326}
        }
        # We'll store booleans as strings to avoid field-type confusion
        attrs = {
            "id":   r["id"],
            "name": r["name"],
            "lon":  r["lon"],
            "lat":  r["lat"],
            "close_river":  str(r["close_river"]),
            "close_coast":  str(r["close_coast"])
        }
        feats.append(Feature(geometry=geom, attributes=attrs))
    
    # 2) Define the "fields" array for each attribute
    fields = [
        {
            "name": "id",
            "type": "esriFieldTypeString",
            "alias": "id"
        },
        {
            "name": "name",
            "type": "esriFieldTypeString",
            "alias": "name"
        },
        {
            "name": "lon",
            "type": "esriFieldTypeDouble",
            "alias": "lon"
        },
        {
            "name": "lat",
            "type": "esriFieldTypeDouble",
            "alias": "lat"
        },
        {
            "name": "close_river",
            "type": "esriFieldTypeString",
            "alias": "close_river"
        },
        {
            "name": "close_coast",
            "type": "esriFieldTypeString",
            "alias": "close_coast"
        }
    ]

    # 3) Create the FeatureSet with geometry type + fields
    fs = FeatureSet(
        features=feats,
        geometry_type="esriGeometryPoint",
        spatial_reference={"wkid": 4326},
        fields=fields
    )
    return fs

# %%
###############################################################################
# G) Create FeatureSets for each layer: All, close_river, close_coast
###############################################################################

all_fs = make_featureset(results, "All Erratics")

close_river_fs = make_featureset(
    [r for r in results if r["close_river"]], 
    "Close to Rivers"
)
close_coast_fs = make_featureset(
    [r for r in results if r["close_coast"]],
    "Close to Coast"
)

# %%
###############################################################################
# H) Define some simple symbols for the map
###############################################################################

sym_all = SimpleMarkerSymbolEsriSMS(
    style=SimpleMarkerSymbolStyle.esri_sms_circle,
    color=[0, 0, 255, 128],
    outline=SimpleLineSymbolEsriSLS(color=[255,255,255], width=1)
)
sym_river = SimpleMarkerSymbolEsriSMS(
    style=SimpleMarkerSymbolStyle.esri_sms_circle,
    color=[255, 0, 0, 128],
    outline=SimpleLineSymbolEsriSLS(color=[255,255,255], width=1)
)
sym_coast = SimpleMarkerSymbolEsriSMS(
    style=SimpleMarkerSymbolStyle.esri_sms_circle,
    color=[0, 255, 0, 128],
    outline=SimpleLineSymbolEsriSLS(color=[255,255,255], width=1)
)

# %%
###############################################################################
# I) Create a map and display it
###############################################################################

my_map = gis.map("Washington, USA")
my_map
# Out:
# Map(center=[4706222.166681878, -8573817.429310536], extent={'xmin': -8585394.656353038, 'ymin': 4691358.594985…

# %%
###############################################################################
# J) Add the layers to the map
###############################################################################

# Draw each set as a toggleable layer (label)
my_map.content.draw(shape=all_fs, symbol=sym_all)
my_map.content.draw(shape=close_river_fs, symbol=sym_river)
my_map.content.draw(shape=close_coast_fs, symbol=sym_coast)

# %%
###############################################################################
# K) Print results
###############################################################################

print("\n[INFO] Done. Below is an interactive ArcGIS MapView (in Jupyter).")
print("You can toggle the layers in the layer list.\n")
print("----- RESULTS -----")
for r in results:
    print(f"ID={r['id']} | Name={r['name']} | lat={r['lat']} lon={r['lon']} | "
            f"CloseToRiver={r['close_river']} | CloseToCoast={r['close_coast']}")
# Out:
# [INFO] Done. Below is an interactive ArcGIS MapView (in Jupyter).
# You can toggle the layers in the layer list.
#
# ----- RESULTS -----
# ID=1 | Name=Denali Erratic | lat=63.721633 lon=-148.9658 | CloseToRiver=False | CloseToCoast=False
# ID=2 | Name=Williwaw Erratic | lat=60.7845 lon=-148.87425 | CloseToRiver=False | CloseToCoast=False
# ID=3 | Name=Mendenhall Glacier Erratics | lat=58.491255 lon=-134.523227 | CloseToRiver=False | CloseToCoast=False
# ID=4 | Name=Big Rock | lat=49.989773 lon=-125.225808 | CloseToRiver=False | CloseToCoast=False
# ID=5 | Name=Bellevue Erratic / Sheridan Erratic | lat=45.117361 lon=-123.316211 | CloseToRiver=False | CloseToCoast=False
# ID=6 | Name=Yamhill Valley Erratic | lat=45.14 lon=-123.292778 | CloseToRiver=False | CloseToCoast=False
# ID=7 | Name=Shasta Court Erratic | lat=49.266017 lon=-122.8421 | CloseToRiver=False | CloseToCoast=False
# ID=8 | Name=White Rock | lat=49.01995 lon=-122.802519 | CloseToRiver=False | CloseToCoast=False
# ID=9 | Name=H Street Erratic | lat=48.994108 lon=-122.726207 | CloseToRiver=False | CloseToCoast=False
# ID=10 | Name=Big Rock | lat=48.210283 lon=-122.686817 | CloseToRiver=False | CloseToCoast=False
# ID=11 | Name=White Rock | lat=47.893217 lon=-122.642983 | CloseToRiver=False | CloseToCoast=False
# ID=12 | Name=Willamette Meteorite | lat=45.377041 lon=-122.637099 | CloseToRiver=False | CloseToCoast=False
# ID=13 | Name=Ferndale Erratics | lat=48.869213 lon=-122.593162 | CloseToRiver=False | CloseToCoast=False
# ID=14 | Name=Frog Rock & Ladybug Rock | lat=47.6958 lon=-122.52355 | CloseToRiver=False | CloseToCoast=False
# ID=15 | Name=Donovan Avenue Erratic | lat=48.717272 lon=-122.474638 | CloseToRiver=False | CloseToCoast=False
# ID=16 | Name=Arroyo Park Erratic | lat=48.68492 lon=-122.460352 | CloseToRiver=False | CloseToCoast=False
# ID=17 | Name=Waterman Rock | lat=48.054782 lon=-122.459708 | CloseToRiver=False | CloseToCoast=False
# ID=18 | Name=Aldergrove Erratic / Big Rock | lat=49.008588 lon=-122.448921 | CloseToRiver=False | CloseToCoast=False
# ID=19 | Name=Edmonds Way Erratic | lat=47.789133 lon=-122.35475 | CloseToRiver=False | CloseToCoast=False
# ID=20 | Name=Ravenna Park Erratic | lat=47.6702 lon=-122.30223 | CloseToRiver=False | CloseToCoast=False
# ID=21 | Name=Wedgwood Rock | lat=47.680839 lon=-122.2973 | CloseToRiver=False | CloseToCoast=False
# ID=22 | Name=Saar Creek Erratic | lat=48.955768 lon=-122.201206 | CloseToRiver=False | CloseToCoast=False
# ID=23 | Name=Indian Rock | lat=37.252776 lon=-122.121642 | CloseToRiver=False | CloseToCoast=False
# ID=24 | Name=Lake Stevens Erratic | lat=47.996933 lon=-122.115067 | CloseToRiver=False | CloseToCoast=False
# ID=25 | Name=Fantastic Erratic | lat=47.530237 lon=-122.080479 | CloseToRiver=False | CloseToCoast=False
# ID=26 | Name=Big Rock | lat=47.725617 lon=-121.98645 | CloseToRiver=False | CloseToCoast=False
# ID=27 | Name=Yeager Rock | lat=47.815733 lon=-119.55305 | CloseToRiver=False | CloseToCoast=False
# ID=28 | Name=Olmsted Point Erratics | lat=37.810723 lon=-119.485059 | CloseToRiver=False | CloseToCoast=False
# ID=29 | Name=Omak Rock | lat=48.23503 lon=-119.36667 | CloseToRiver=False | CloseToCoast=False
# ID=30 | Name=Steamboat Rock | lat=47.863518 lon=-119.133417 | CloseToRiver=False | CloseToCoast=False
# ID=31 | Name=Lochend Erratic | lat=51.489267 lon=-114.306517 | CloseToRiver=False | CloseToCoast=False
# ID=32 | Name=Sienna Hills Erratic | lat=51.02595 lon=-114.171883 | CloseToRiver=False | CloseToCoast=False
# ID=33 | Name=Kincora Erratic | lat=51.156333 lon=-114.125233 | CloseToRiver=False | CloseToCoast=False
# ID=34 | Name=Nose Hill Erratic | lat=51.099922 lon=-114.113071 | CloseToRiver=False | CloseToCoast=False
# ID=35 | Name=Hidden Valley Erratic | lat=51.14855 lon=-114.1119 | CloseToRiver=False | CloseToCoast=False
# ID=36 | Name=Rubbing Stone | lat=51.112008 lon=-114.090847 | CloseToRiver=False | CloseToCoast=False
# ID=37 | Name=Big Rock | lat=50.705883 lon=-114.076422 | CloseToRiver=False | CloseToCoast=False
# ID=38 | Name=Nose Creek Erratic | lat=51.13405 lon=-114.065983 | CloseToRiver=False | CloseToCoast=False
# ID=39 | Name=Glenwood Erratic | lat=49.366674 lon=-113.518605 | CloseToRiver=False | CloseToCoast=False
# ID=40 | Name=Yellowstone Erratic | lat=44.729133 lon=-110.4725 | CloseToRiver=False | CloseToCoast=False
# ID=41 | Name=Flaxcombe Erratic | lat=51.474183 lon=-109.6228 | CloseToRiver=False | CloseToCoast=False
# ID=42 | Name=Indian Lake Medicine Rock | lat=47.730457 lon=-107.870383 | CloseToRiver=False | CloseToCoast=False
# ID=43 | Name=Sleeping Buffalo Rock | lat=48.435279 lon=-107.597036 | CloseToRiver=False | CloseToCoast=False
# ID=44 | Name=Misateni | lat=51.129793 lon=-106.572064 | CloseToRiver=False | CloseToCoast=False
# ID=45 | Name=Mills Lake Erratic | lat=40.29145 lon=-105.642783 | CloseToRiver=False | CloseToCoast=False
# ID=46 | Name=Buffalo Stone | lat=50.901 lon=-105.6342 | CloseToRiver=False | CloseToCoast=False
# ID=47 | Name=Writing Rock | lat=48.780357 lon=-103.884351 | CloseToRiver=False | CloseToCoast=False
# ID=48 | Name=Horizon Middle School Erratics | lat=46.856233 lon=-100.802733 | CloseToRiver=False | CloseToCoast=False
# ID=49 | Name=Prayer Rock | lat=45.44515 lon=-99.027733 | CloseToRiver=False | CloseToCoast=False
# ID=50 | Name=Writing Rock | lat=46.520804 lon=-97.926213 | CloseToRiver=False | CloseToCoast=False
# ID=51 | Name=Standing Rock | lat=46.623601 lon=-97.908518 | CloseToRiver=False | CloseToCoast=False
# ID=52 | Name=Medicine Rock | lat=49.9087 lon=-97.53595 | CloseToRiver=False | CloseToCoast=False
# ID=53 | Name=Thunder Bird's Track | lat=45.587174 lon=-97.13704 | CloseToRiver=False | CloseToCoast=False
# ID=54 | Name=Thunder Bird's Track's Brother | lat=45.589947 lon=-97.096747 | CloseToRiver=False | CloseToCoast=False
# ID=55 | Name=Sacred Rock | lat=45.610122 lon=-96.835616 | CloseToRiver=False | CloseToCoast=False
# ID=56 | Name=Pilot Rock | lat=42.695817 lon=-95.553062 | CloseToRiver=False | CloseToCoast=False
# ID=57 | Name=Falcon Creek Erratic | lat=49.692717 lon=-95.338267 | CloseToRiver=False | CloseToCoast=False
# ID=58 | Name=Gull Point State Park | lat=43.372868 lon=-95.162472 | CloseToRiver=False | CloseToCoast=False
# ID=59 | Name=Lone Rock | lat=43.219372 lon=-94.321724 | CloseToRiver=False | CloseToCoast=False
# ID=60 | Name=Squaw Creek Erratic | lat=42.037041 lon=-93.650891 | CloseToRiver=False | CloseToCoast=False
# ID=61 | Name=Big Rock / Tun-Can / Grandfather | lat=44.742968 lon=-93.402614 | CloseToRiver=False | CloseToCoast=False
# ID=62 | Name=Woodland Erratic | lat=44.274567 lon=-93.335717 | CloseToRiver=False | CloseToCoast=False
# ID=63 | Name=Bairdstown Church Erratic | lat=40.284971 lon=-93.191456 | CloseToRiver=False | CloseToCoast=False
# ID=64 | Name=Granite Boulder | lat=42.244722 lon=-93.064167 | CloseToRiver=False | CloseToCoast=False
# ID=65 | Name=The Sentinel | lat=41.698615 lon=-93.046939 | CloseToRiver=False | CloseToCoast=False
# ID=66 | Name=Sleeping Boulder | lat=41.698565 lon=-93.046378 | CloseToRiver=False | CloseToCoast=False
# ID=67 | Name=Grammer Grove Erratic | lat=42.16685 lon=-93.031917 | CloseToRiver=False | CloseToCoast=False
# ID=68 | Name=Red Rock Boulder | lat=44.872763 lon=-92.993125 | CloseToRiver=False | CloseToCoast=False
# ID=69 | Name=St Peter's Rock | lat=43.167097 lon=-92.356772 | CloseToRiver=False | CloseToCoast=False
# ID=70 | Name=Black Hawk County Erratic | lat=42.501197 lon=-92.33654 | CloseToRiver=True | CloseToCoast=False
# ID=71 | Name=Split Rock | lat=42.913331 lon=-92.2385 | CloseToRiver=False | CloseToCoast=False
# ID=72 | Name=Five Sisters Boulders | lat=42.315256 lon=-92.00346 | CloseToRiver=False | CloseToCoast=False
# ID=73 | Name=Crumbacher Erratic | lat=42.4333 lon=-91.970967 | CloseToRiver=False | CloseToCoast=False
# ID=74 | Name=Stone Man | lat=42.851153 lon=-91.845139 | CloseToRiver=False | CloseToCoast=False
# ID=75 | Name=Big Rock | lat=42.25495 lon=-91.62775 | CloseToRiver=False | CloseToCoast=False
# ID=76 | Name=The Rock | lat=41.990552 lon=-91.627172 | CloseToRiver=False | CloseToCoast=False
# ID=77 | Name=White Cross Rock | lat=42.524559 lon=-90.668568 | CloseToRiver=False | CloseToCoast=False
# ID=78 | Name=Ice Age Trail Erratic | lat=45.405375 lon=-89.465189 | CloseToRiver=False | CloseToCoast=False
# ID=79 | Name=Chamberlin Erratic | lat=43.076784 lon=-89.426668 | CloseToRiver=False | CloseToCoast=False
# ID=80 | Name=Church Street Erratic | lat=40.596817 lon=-89.128917 | CloseToRiver=False | CloseToCoast=False
# ID=81 | Name=Elephant Rock | lat=38.434031 lon=-88.862428 | CloseToRiver=False | CloseToCoast=False
# ID=82 | Name=Chandler Cemetery Erratic | lat=40.0509 lon=-88.763033 | CloseToRiver=False | CloseToCoast=False
# ID=83 | Name=Wolf Creek Erratic | lat=39.4776 lon=-88.681533 | CloseToRiver=False | CloseToCoast=False
# ID=84 | Name=Little Stinker | lat=41.6948 lon=-88.1232 | CloseToRiver=False | CloseToCoast=False
# ID=85 | Name=Schoolhouse Memorial Rock | lat=41.716133 lon=-88.115433 | CloseToRiver=False | CloseToCoast=False
# ID=86 | Name=Fort St. Joseph Erratic | lat=41.812989 lon=-86.260762 | CloseToRiver=False | CloseToCoast=False
# ID=87 | Name=Eager Beaver Erratic | lat=40.029283 lon=-86.0328 | CloseToRiver=False | CloseToCoast=False
# ID=88 | Name=Grand Valley Erratics | lat=42.969017 lon=-85.9523 | CloseToRiver=False | CloseToCoast=False
# ID=89 | Name=Artesian Erratics | lat=40.3167 lon=-85.309433 | CloseToRiver=False | CloseToCoast=False
# ID=90 | Name=Hidden Lake Gardens Erratic | lat=42.0226 lon=-84.107367 | CloseToRiver=False | CloseToCoast=False
# ID=91 | Name=Brassfield Erratic | lat=39.448735 lon=-84.08393 | CloseToRiver=False | CloseToCoast=False
# ID=92 | Name=Erie Erratic | lat=42.075233 lon=-83.198933 | CloseToRiver=False | CloseToCoast=False
# ID=93 | Name=Wyman Woods Erratic | lat=39.978229 lon=-83.043599 | CloseToRiver=False | CloseToCoast=False
# ID=94 | Name=Orton Hall Erratic | lat=40.001328 lon=-83.014564 | CloseToRiver=False | CloseToCoast=False
# ID=95 | Name=Rush Creek Erratic | lat=40.08395 lon=-83.007133 | CloseToRiver=False | CloseToCoast=False
# ID=96 | Name=Sunbury Erratic | lat=40.248504 lon=-82.830746 | CloseToRiver=False | CloseToCoast=False
# ID=97 | Name=Balancing Rock | lat=40.3226 lon=-78.131 | CloseToRiver=False | CloseToCoast=False
# ID=98 | Name=Bleasdell Boulder | lat=44.148833 lon=-77.588496 | CloseToRiver=False | CloseToCoast=False
# ID=99 | Name=Skenandoah Boulder | lat=43.076713 lon=-75.618942 | CloseToRiver=False | CloseToCoast=False
# ID=100 | Name=Mouse Cradle Balancing Rock | lat=40.91172 lon=-74.43818 | CloseToRiver=False | CloseToCoast=False
# ID=101 | Name=Elephant Rock | lat=40.901447 lon=-74.407997 | CloseToRiver=False | CloseToCoast=False
# ID=102 | Name=Bear Rock / 'Bare Roke' | lat=40.958505 lon=-74.389862 | CloseToRiver=False | CloseToCoast=False
# ID=103 | Name=Kinnelon Tripod Rock | lat=40.960038 lon=-74.384496 | CloseToRiver=False | CloseToCoast=False
# ID=104 | Name=Whale Head Rock | lat=40.963761 lon=-74.379243 | CloseToRiver=False | CloseToCoast=False
# ID=105 | Name=Indian Rock | lat=41.689981 lon=-74.355505 | CloseToRiver=False | CloseToCoast=False
# ID=106 | Name=Patterson's Pellet | lat=41.713289 lon=-74.24509 | CloseToRiver=False | CloseToCoast=False
# ID=107 | Name=Sitting Hen Rock | lat=41.062883 lon=-74.237601 | CloseToRiver=False | CloseToCoast=False
# ID=108 | Name=Glen Rock | lat=40.962698 lon=-74.134903 | CloseToRiver=False | CloseToCoast=False
# ID=109 | Name=Indian Rock | lat=41.113575 lon=-74.129133 | CloseToRiver=False | CloseToCoast=False
# ID=110 | Name=Indian Rock | lat=41.135929 lon=-74.118477 | CloseToRiver=False | CloseToCoast=False
# ID=111 | Name=Sugarloaf Rock | lat=40.630498 lon=-74.088118 | CloseToRiver=False | CloseToCoast=False
# ID=112 | Name=Central Park Erratic | lat=40.770594 lon=-73.974518 | CloseToRiver=False | CloseToCoast=False
# ID=113 | Name=Tory Rock | lat=43.2648 lon=-73.957017 | CloseToRiver=False | CloseToCoast=False
# ID=114 | Name=New York Botanical Garden Erratic | lat=40.863879 lon=-73.878693 | CloseToRiver=False | CloseToCoast=False
# ID=115 | Name=Rockingstone | lat=40.847968 lon=-73.877838 | CloseToRiver=False | CloseToCoast=False
# ID=116 | Name=Bear Den Erratics | lat=40.848937 lon=-73.877603 | CloseToRiver=False | CloseToCoast=False
# ID=117 | Name=Ditmars Blvd Pet Rock | lat=40.767853 lon=-73.867447 | CloseToRiver=False | CloseToCoast=False
# ID=118 | Name=Split Rock | lat=40.886261 lon=-73.814758 | CloseToRiver=False | CloseToCoast=False
# ID=119 | Name=Glover's Rock | lat=40.865108 lon=-73.802247 | CloseToRiver=False | CloseToCoast=False
# ID=120 | Name=Rocking Stone | lat=40.940186 lon=-73.767773 | CloseToRiver=False | CloseToCoast=False
# ID=121 | Name=Shelter Rock / Milestone Rock | lat=40.789311 lon=-73.691139 | CloseToRiver=False | CloseToCoast=False
# ID=122 | Name=North Salem Dolmen | lat=41.664167 lon=-73.572 | CloseToRiver=False | CloseToCoast=False
# ID=123 | Name=Target Rock | lat=40.929658 lon=-73.430375 | CloseToRiver=False | CloseToCoast=False
# ID=124 | Name=Simon's Rock | lat=42.207759 lon=-73.374402 | CloseToRiver=False | CloseToCoast=False
# ID=125 | Name=Balance Rock | lat=42.5106 lon=-73.273883 | CloseToRiver=False | CloseToCoast=False
# ID=126 | Name=Hiram's Tomb | lat=42.275745 lon=-72.97961 | CloseToRiver=False | CloseToCoast=False
# ID=127 | Name=Knightville Basin Erratic | lat=42.329317 lon=-72.854917 | CloseToRiver=False | CloseToCoast=False
# ID=128 | Name=Picnic Rock | lat=43.548805 lon=-72.815677 | CloseToRiver=False | CloseToCoast=False
# ID=129 | Name=Judge's Cave | lat=41.252111 lon=-72.538196 | CloseToRiver=False | CloseToCoast=False
# ID=130 | Name=Quinipet Boulders | lat=41.070534 lon=-72.381155 | CloseToRiver=False | CloseToCoast=False
# ID=131 | Name=Chipmunk Boulder | lat=41.390018 lon=-72.321858 | CloseToRiver=False | CloseToCoast=False
# ID=132 | Name=Tippin Rock | lat=42.824051 lon=-72.286786 | CloseToRiver=False | CloseToCoast=False
# ID=133 | Name=Vessel Rock | lat=43.031625 lon=-72.275002 | CloseToRiver=False | CloseToCoast=False
# ID=134 | Name=Wolf Rock | lat=41.75933 lon=-72.21258 | CloseToRiver=False | CloseToCoast=False
# ID=135 | Name=Rockingstone | lat=42.436019 lon=-72.1575 | CloseToRiver=False | CloseToCoast=False
# ID=136 | Name=Cauchegan Rock / Sheegan Rock | lat=41.470654 lon=-72.123411 | CloseToRiver=False | CloseToCoast=False
# ID=137 | Name=Rum Rock | lat=42.421658 lon=-72.120911 | CloseToRiver=False | CloseToCoast=False
# ID=138 | Name=Indian Rock | lat=42.457075 lon=-72.104545 | CloseToRiver=False | CloseToCoast=False
# ID=139 | Name=Profile Rock | lat=42.607452 lon=-72.075353 | CloseToRiver=False | CloseToCoast=False
# ID=140 | Name=Frog Rock | lat=41.867927 lon=-72.05038 | CloseToRiver=False | CloseToCoast=False
# ID=141 | Name=Sunset Rock | lat=41.324252 lon=-72.030862 | CloseToRiver=False | CloseToCoast=False
# ID=142 | Name=Split Rock | lat=41.321197 lon=-72.022306 | CloseToRiver=False | CloseToCoast=False
# ID=143 | Name=Jemima's Rock / Canopie Rock | lat=41.330919 lon=-72.014887 | CloseToRiver=False | CloseToCoast=False
# ID=144 | Name=Rocking Boulder | lat=41.327862 lon=-71.990594 | CloseToRiver=False | CloseToCoast=False
# ID=145 | Name=Parking Lot Erratic | lat=41.344656 lon=-71.94998 | CloseToRiver=False | CloseToCoast=False
# ID=146 | Name=Rollstone Boulder | lat=42.586677 lon=-71.805949 | CloseToRiver=False | CloseToCoast=False
# ID=147 | Name=Pulpit Rock | lat=43.40514 lon=-71.739632 | CloseToRiver=False | CloseToCoast=False
# ID=148 | Name=Frog Rock | lat=42.934017 lon=-71.721933 | CloseToRiver=False | CloseToCoast=False
# ID=149 | Name=Indian Rock | lat=41.656563 lon=-71.713305 | CloseToRiver=False | CloseToCoast=False
# ID=150 | Name=Boise Rock | lat=44.140751 lon=-71.690585 | CloseToRiver=False | CloseToCoast=False
# ID=151 | Name=Rowlandson Boulder | lat=42.4534 lon=-71.675059 | CloseToRiver=False | CloseToCoast=False
# ID=152 | Name=Indian Rock | lat=42.954956 lon=-71.612765 | CloseToRiver=False | CloseToCoast=False
# ID=153 | Name=Settler's Rock | lat=41.224795 lon=-71.566936 | CloseToRiver=False | CloseToCoast=False
# ID=154 | Name=Cobble Rock / Coblin Rock | lat=41.982984 lon=-71.532058 | CloseToRiver=False | CloseToCoast=False
# ID=155 | Name=Egg Rock | lat=42.5037 lon=-71.434267 | CloseToRiver=False | CloseToCoast=False
# ID=156 | Name=Elevation Boulder | lat=41.870562 lon=-71.383569 | CloseToRiver=False | CloseToCoast=False
# ID=157 | Name=Fairy Rock / Bates Boulder | lat=42.31552 lon=-71.308165 | CloseToRiver=False | CloseToCoast=False
# ID=158 | Name=Bartlett Boulder | lat=44.092788 lon=-71.288474 | CloseToRiver=False | CloseToCoast=False
# ID=159 | Name=Glen Boulder | lat=44.237927 lon=-71.275831 | CloseToRiver=False | CloseToCoast=False
# ID=160 | Name=Ordination Rock | lat=43.859442 lon=-71.264433 | CloseToRiver=False | CloseToCoast=False
# ID=161 | Name=Revere Rock | lat=42.437326 lon=-71.246971 | CloseToRiver=False | CloseToCoast=False
# ID=162 | Name=Churchill Rock | lat=43.12007 lon=-71.18532 | CloseToRiver=False | CloseToCoast=False
# ID=163 | Name=Madison Boulder | lat=43.9302 lon=-71.16968 | CloseToRiver=False | CloseToCoast=False
# ID=164 | Name=Rolling Rock | lat=41.693452 lon=-71.130181 | CloseToRiver=False | CloseToCoast=False
# ID=165 | Name=Sliding Rock | lat=41.693686 lon=-71.126327 | CloseToRiver=False | CloseToCoast=False
# ID=166 | Name=Quimby's Pillow | lat=44.08128 lon=-71.119835 | CloseToRiver=False | CloseToCoast=False
# ID=167 | Name=Dighton Rock | lat=41.812934 lon=-71.110424 | CloseToRiver=False | CloseToCoast=False
# ID=168 | Name=Washington Boulder | lat=44.004418 lon=-71.107877 | CloseToRiver=False | CloseToCoast=False
# ID=169 | Name=Elephant Rock | lat=42.645363 lon=-71.092025 | CloseToRiver=False | CloseToCoast=False
# ID=170 | Name=Fairview Rock | lat=42.292084 lon=-71.046092 | CloseToRiver=False | CloseToCoast=False
# ID=171 | Name=Ordway Boulder | lat=42.748805 lon=-71.024753 | CloseToRiver=False | CloseToCoast=False
# ID=172 | Name=Cradle Rock | lat=42.749393 lon=-71.017956 | CloseToRiver=False | CloseToCoast=False
# ID=173 | Name=Wigwam Rock | lat=42.520576 lon=-70.981956 | CloseToRiver=False | CloseToCoast=False
# ID=174 | Name=Phaeton Rock / Cannon Rock | lat=42.50373 lon=-70.96862 | CloseToRiver=False | CloseToCoast=False
# ID=175 | Name=The Weymouth Sphinx | lat=42.207964 lon=-70.963044 | CloseToRiver=False | CloseToCoast=False
# ID=176 | Name=Ship Rock | lat=42.520115 lon=-70.957314 | CloseToRiver=False | CloseToCoast=False
# ID=177 | Name=House Rock | lat=42.214334 lon=-70.945019 | CloseToRiver=False | CloseToCoast=False
# ID=178 | Name=Perched Rock | lat=42.179041 lon=-70.923129 | CloseToRiver=False | CloseToCoast=False
# ID=179 | Name=Hand Rock | lat=41.900977 lon=-70.891926 | CloseToRiver=False | CloseToCoast=False
# ID=180 | Name=Carsey's Rock | lat=42.758691 lon=-70.869627 | CloseToRiver=False | CloseToCoast=False
# ID=181 | Name=Bouve Boulder | lat=42.249526 lon=-70.867986 | CloseToRiver=False | CloseToCoast=False
# ID=182 | Name=Haystack Boulder | lat=42.76779 lon=-70.846991 | CloseToRiver=False | CloseToCoast=False
# ID=183 | Name=Burbank Boulder | lat=42.20515 lon=-70.844006 | CloseToRiver=False | CloseToCoast=False
# ID=184 | Name=Witch Rock | lat=41.726564 lon=-70.839939 | CloseToRiver=False | CloseToCoast=False
# ID=185 | Name=Split Rock | lat=41.655991 lon=-70.82144 | CloseToRiver=False | CloseToCoast=False
# ID=186 | Name=Bung-stopper Rock | lat=42.592991 lon=-70.820263 | CloseToRiver=False | CloseToCoast=False
# ID=187 | Name=Toad Rock | lat=41.319407 lon=-70.803577 | CloseToRiver=False | CloseToCoast=False
# ID=188 | Name=Agassiz Rock / Sunset Rock | lat=42.596485 lon=-70.766345 | CloseToRiver=False | CloseToCoast=False
# ID=189 | Name=Split Rock | lat=41.699178 lon=-70.765228 | CloseToRiver=False | CloseToCoast=False
# ID=190 | Name=The Sugar Loaf | lat=41.357547 lon=-70.750104 | CloseToRiver=False | CloseToCoast=False
# ID=191 | Name=Stonecutter's Rock | lat=41.356502 lon=-70.738917 | CloseToRiver=False | CloseToCoast=False
# ID=192 | Name=The Devil's Bed | lat=41.35273 lon=-70.735555 | CloseToRiver=False | CloseToCoast=False
# ID=193 | Name=Wakosim's Rock | lat=41.395891 lon=-70.703448 | CloseToRiver=False | CloseToCoast=False
# ID=194 | Name=Tilting Rock | lat=42.657502 lon=-70.67705 | CloseToRiver=False | CloseToCoast=False
# ID=195 | Name=Plymouth Rock | lat=41.958068 lon=-70.662112 | CloseToRiver=False | CloseToCoast=False
# ID=196 | Name=Babson Boulders | lat=42.636492 lon=-70.661022 | CloseToRiver=False | CloseToCoast=False
# ID=197 | Name=Raccoon Rocks | lat=42.64932 lon=-70.639782 | CloseToRiver=False | CloseToCoast=False
# ID=198 | Name=Shade Rock | lat=41.440703 lon=-70.630554 | CloseToRiver=False | CloseToCoast=False
# ID=199 | Name=Rumford Erratic | lat=44.512253 lon=-70.619815 | CloseToRiver=False | CloseToCoast=False
# ID=200 | Name=White Horse Rock / Flag Rock | lat=41.935881 lon=-70.558809 | CloseToRiver=False | CloseToCoast=False
# ID=201 | Name=Dagget Rock | lat=44.848548 lon=-70.304896 | CloseToRiver=False | CloseToCoast=False
# ID=202 | Name=Hokum Rock | lat=41.732467 lon=-70.172583 | CloseToRiver=False | CloseToCoast=False
# ID=203 | Name=Doane Rock | lat=41.84445 lon=-69.95782 | CloseToRiver=False | CloseToCoast=False
# ID=204 | Name=Katahdin Erratic | lat=45.78365 lon=-68.97425 | CloseToRiver=False | CloseToCoast=False
# ID=205 | Name=Bubble Rock | lat=44.342778 lon=-68.256111 | CloseToRiver=False | CloseToCoast=False
# ID=206 | Name=The Jelly Bean | lat=44.352823 lon=-68.224132 | CloseToRiver=False | CloseToCoast=False
# ID=207 | Name=Tunk Giants | lat=44.600967 lon=-68.052083 | CloseToRiver=False | CloseToCoast=False
# ID=208 | Name=Gibraltar Rock | lat=44.867883 lon=-66.937717 | CloseToRiver=False | CloseToCoast=False
# ID=209 | Name=Island's Erratic | lat=43.76525 lon=-65.33795 | CloseToRiver=False | CloseToCoast=False
# ID=210 | Name=Pocket Erratic | lat=43.874317 lon=-64.9631 | CloseToRiver=False | CloseToCoast=False
# ID=211 | Name=Kidston Lake Rocking Stone | lat=44.595783 lon=-63.6178 | CloseToRiver=False | CloseToCoast=False
# ID=212 | Name=Lord & Lady Gulch Erratic | lat=49.6816 lon=-54.41735 | CloseToRiver=False | CloseToCoast=False
# ID=213 | Name=The Lantern | lat=47.607699 lon=-53.22458 | CloseToRiver=False | CloseToCoast=False

# %%
###############################################################################
# L) Export the map to an HTML file
###############################################################################

file_dir = os.path.join(os.getcwd(), "maps")
if not os.path.isdir(file_dir):
    os.mkdir(file_dir)

file_path = os.path.join(file_dir, "erratics-layers.html")

my_map.export_to_html(file_path, title="Erratics with Layers")
# Out:
# True
